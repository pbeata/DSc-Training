# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset is one of the most popular ones for machine learning. You can read a lot about it online and have probably already heard of it: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# We didn't want to use it in the lectures, but believe that it would be very interesting for you to try it out (and maybe read about it on your own).
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.
#
#
# Tasks for this investigation:
# * Start by creating 2 clusters.
# * Then standardize the data and try again. Does it make a difference?
# * Use the Elbow rule to determine how many clusters there really are.

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
raw_data = pd.read_csv('../data/iris.csv')
raw_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
raw_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Plot the data

# %% [markdown]
# For this exercise, try to cluster the iris flowers by the shape of their sepal.
#
# <i> Use the 'sepal_length' and 'sepal_width' variables.</i>

# %%
plt.scatter(raw_data['sepal_length'], raw_data['sepal_width'])

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

# plt.xlim(0, 10)
# plt.ylim(0, 6)

plt.show()

# %% [markdown]
# # Clustering (unscaled data)

# %% [markdown]
# Separate the original data into 2 clusters.

# %%
kmeans = KMeans(2)
kmeans.fit(raw_data)
# Out:
# KMeans(n_clusters=2)

# %%
cluster_data = raw_data.copy()
cluster_data['cluster'] = kmeans.fit_predict(raw_data)
cluster_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  cluster
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        0
# 146           6.3          2.5           5.0          1.9        0
# 147           6.5          3.0           5.2          2.0        0
# 148           6.2          3.4           5.4          2.3        0
# 149           5.9          3.0           5.1          1.8        0
#
# [150 rows x 5 columns]

# %%
plt.scatter(raw_data['sepal_length'], raw_data['sepal_width'], c=cluster_data['cluster'], cmap='rainbow')

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

plt.show()

# %% [markdown]
# # Standardize the variables

# %% [markdown]
# Import and use the <i> method </i> function from sklearn to standardize the data.

# %%
# standardize the variables
from sklearn import preprocessing
data_scaled = preprocessing.scale(raw_data)
data_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %% [markdown]
# # Clustering (scaled data)

# %%
kmeans_scaled = KMeans(2)
kmeans_scaled.fit(data_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
data_scaled_clustered = pd.DataFrame(data_scaled)
data_scaled_clustered['cluster'] = kmeans_scaled.fit_predict(data_scaled)
data_scaled_clustered
# Out:
#             0         1         2         3  cluster
# 0   -0.900681  1.032057 -1.341272 -1.312977        0
# 1   -1.143017 -0.124958 -1.341272 -1.312977        0
# 2   -1.385353  0.337848 -1.398138 -1.312977        0
# 3   -1.506521  0.106445 -1.284407 -1.312977        0
# 4   -1.021849  1.263460 -1.341272 -1.312977        0
# ..        ...       ...       ...       ...      ...
# 145  1.038005 -0.124958  0.819624  1.447956        1
# 146  0.553333 -1.281972  0.705893  0.922064        1
# 147  0.795669 -0.124958  0.819624  1.053537        1
# 148  0.432165  0.800654  0.933356  1.447956        1
# 149  0.068662 -0.124958  0.762759  0.790591        1
#
# [150 rows x 5 columns]

# %%
data_scaled_clustered.describe()
# Out:
#                   0             1             2             3     cluster
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02  150.000000
# mean  -2.775558e-16 -5.140333e-16  1.154632e-16  9.251859e-16    0.666667
# std    1.003350e+00  1.003350e+00  1.003350e+00  1.003350e+00    0.472984
# min   -1.870024e+00 -2.438987e+00 -1.568735e+00 -1.444450e+00    0.000000
# 25%   -9.006812e-01 -5.877635e-01 -1.227541e+00 -1.181504e+00    0.000000
# 50%   -5.250608e-02 -1.249576e-01  3.362659e-01  1.332259e-01    1.000000
# 75%    6.745011e-01  5.692513e-01  7.627586e-01  7.905908e-01    1.000000
# max    2.492019e+00  3.114684e+00  1.786341e+00  1.710902e+00    1.000000

# %%
plt.scatter(data_scaled_clustered[0], data_scaled_clustered[1], c=data_scaled_clustered['cluster'], cmap='rainbow')

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

plt.show()

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
# calculate the WCSS for any number of clusters up to N
# WCSS: within clusters sum of squares

N = 10
WCSS = []
x_scaled = pd.DataFrame(data_scaled)

for i in range (1, N+1):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    WCSS.append(kmeans.inertia_)

WCSS
# Out:
# [600.0000000000003,
#  223.73200573676343,
#  140.96837895511072,
#  114.6822160993797,
#  91.19197002146461,
#  81.74373561668146,
#  70.90757143446565,
#  63.57012825503546,
#  54.90360892817521,
#  47.31730364030484]

# %% [markdown]
# ### The Elbow Method

# %%
plt.figure(figsize=(6,3), dpi=100)

n = np.arange(1, N+1)
plt.plot(n, WCSS, 'ko-')
plt.ylabel('WCSS')
plt.xlabel('Clusters')

plt.show()

# %% [markdown]
# How many clusters are there?

# %%
km3 = KMeans(3)
km3.fit(data_scaled)
data3 = pd.DataFrame(data_scaled)
data3['cluster'] = km3.fit_predict(data_scaled)

# %%
plt.scatter(data3[0], data3[1], c=data3['cluster'], cmap='rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
km5 = KMeans(5)
km5.fit(data_scaled)
data5 = pd.DataFrame(data_scaled)
data5['cluster'] = km5.fit_predict(data_scaled)

# %%
plt.scatter(data5[0], data5[1], c=data5['cluster'], cmap='rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()
