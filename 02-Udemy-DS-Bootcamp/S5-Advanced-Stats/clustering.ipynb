# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('../data/country_clusters.csv')
data
# Out:
#      Country  Latitude  Longitude Language
# 0        USA     44.97    -103.77  English
# 1     Canada     62.40     -96.80  English
# 2     France     46.75       2.40   French
# 3         UK     54.01      -2.53  English
# 4    Germany     51.15      10.40   German
# 5  Australia    -25.45     133.11  English

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %%
# data mapping
data_mapped = data.copy()
data_mapped['Language'] = data_mapped['Language'].map({'English': 0, 'French': 1, 'German': 2})
data_mapped
# Out:
#      Country  Latitude  Longitude  Language
# 0        USA     44.97    -103.77         0
# 1     Canada     62.40     -96.80         0
# 2     France     46.75       2.40         1
# 3         UK     54.01      -2.53         0
# 4    Germany     51.15      10.40         2
# 5  Australia    -25.45     133.11         0

# %% [markdown]
# ### Select the Features

# %%
# clustering by location
x = data.iloc[:, 1:3]
x
# Out:
#    Latitude  Longitude
# 0     44.97    -103.77
# 1     62.40     -96.80
# 2     46.75       2.40
# 3     54.01      -2.53
# 4     51.15      10.40
# 5    -25.45     133.11

# %% [markdown]
# ### Clustering

# %%
kmeans = KMeans(3)  # new KMeans object with 2 clusters

# %%
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3)

# %% [markdown]
# ### Clustering Results

# %%
identified_clusters = kmeans.fit_predict(x)

# %%
identified_clusters
# Out:
# array([2, 2, 1, 1, 1, 0])

# %%
clustered_data = data.copy()

# %%
clustered_data['Cluster'] = identified_clusters
clustered_data
# Out:
#      Country  Latitude  Longitude Language  Cluster
# 0        USA     44.97    -103.77  English        2
# 1     Canada     62.40     -96.80  English        2
# 2     France     46.75       2.40   French        1
# 3         UK     54.01      -2.53  English        1
# 4    Germany     51.15      10.40   German        1
# 5  Australia    -25.45     133.11  English        0

# %%
plt.scatter(clustered_data['Longitude'], clustered_data['Latitude'], c=clustered_data['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %%
x = data_mapped.iloc[:, 3:4]
x
# Out:
#    Language
# 0         0
# 1         0
# 2         1
# 3         0
# 4         2
# 5         0

# %%
kmeans = KMeans(3)
kmeans.fit(x)
id_clusters = kmeans.fit_predict(x)
id_clusters
# Out:
# array([0, 0, 2, 0, 1, 0])

# %%
data_clustered = data_mapped.copy()
data_clustered['Cluster'] = id_clusters
plt.scatter(data_clustered['Longitude'], data_clustered['Latitude'], c=data_clustered['Cluster'], cmap='rainbow');

# %% [markdown]
# ### Exercise

# %%
df = pd.read_csv('../data/countries_exercise.csv')
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
plt.scatter(df['Longitude'], df['Latitude'])
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %%
xx = df.iloc[:, 1:3]

# %%
km = KMeans(8)
km.fit(xx)
# Out:
# KMeans()

# %%
clusters = km.fit_predict(xx)

# %%
df2 = df.copy()
df2['Cluster'] = clusters

# %%
plt.scatter(df2['Longitude'], df2['Latitude'], c=df2['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %%
plt.scatter(df2['Longitude'], df2['Latitude'], c=df2['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %%
plt.scatter(df2['Longitude'], df2['Latitude'], c=df2['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %%
plt.scatter(df2['Longitude'], df2['Latitude'], c=df2['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ### Clustering Categorical Data Exercise
