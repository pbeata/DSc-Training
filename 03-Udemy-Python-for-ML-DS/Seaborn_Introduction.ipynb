# %% [markdown]
# # Seaborn

# %% [markdown]
# ### Scatter Plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('./data/dm_office_sales.csv')
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure()
sns.scatterplot(x='salary', y='sales', data=df);

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x='salary', y='sales', data=df, hue='level of education');

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x='salary', y='sales', data=df, hue='salary');

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x='salary', y='sales', data=df, 
                hue='level of education',
                palette='Dark2',
#                 size='salary'.
                s=200);

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x='salary', y='sales', data=df, 
                hue='level of education',
                palette='Dark2',
                size='salary',
                alpha=0.2);

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x='salary', y='sales', data=df, 
                hue='level of education',
                style='level of education',
                s=200);

plt.savefig('./out/scatter_salary_data.png', dpi=300)

# style should be categorical data

# %% [markdown]
# ### Distribution Plots
#
# * Rug Plot
# * Histograms
# * KDE: Kernel Density Estimation plot (on top of histogram); method of estimating a PDF for

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(12,8), dpi=300)
sns.rugplot(x='salary', data=df, height=0.5);

# %% [markdown]
# **Use these in Seaborn:**
#
# * sns.displot
# * sns.histplot

# %%
# sns.set(style='darkgrid')
# sns.set(style='whitegrid')
# sns.set(style='dark')
# sns.set(style='ticks')

sns.displot(data=df, x='salary', bins=20, 
            color='red', edgecolor='blue',
            lw=1);

# %%
sns.histplot(data=df, x='salary');

# %%
sns.displot(data=df, x='salary', kde=True);

# %%
sns.kdeplot(data=df, x='salary');

# %%
np.random.seed(42)
sample_ages = np.random.randint(0, 100, 200)

# %%
sample_ages
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sample_ages = pd.DataFrame(sample_ages, columns=['age'])
sample_ages
# Out:
#      age
# 0     51
# 1     92
# 2     14
# 3     71
# 4     60
# ..   ...
# 195   76
# 196    2
# 197   69
# 198   71
# 199   26
#
# [200 rows x 1 columns]

# %%
sns.rugplot(data=sample_ages, x='age');

# %%
sns.displot(data=sample_ages, x='age', rug=True, bins=30, kde=True);

# %%
sns.kdeplot(data=sample_ages, x='age');

# %%
sns.kdeplot(data=sample_ages, x='age', clip=[0,100]);

# %%
sns.kdeplot(data=sample_ages, x='age', clip=[0,100], bw_adjust=0.6);

# %%
sns.kdeplot(data=sample_ages, x='age', clip=[0,100], shade=True);

# %% [markdown]
# ### Categorical Plots
#
# * countplot()
# * barplot()

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.countplot(data=df, x='division');

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.countplot(data=df, x='level of education', 
              hue='division', palette='Set2');
# colormap link for matplotlib can be used

# %%
df['level of education'].value_counts()
# Out:
# associate's degree    412
# some college          392
# high school           108
# bachelor's degree      85
# master's degree         3
# Name: level of education, dtype: int64

# %%
plt.figure(figsize=(12,4), dpi=300)
sns.barplot(data=df, x='level of education', y='salary', 
            estimator=np.mean, ci='sd');

# %%
plt.figure(figsize=(12,4), dpi=300)
sns.barplot(data=df, x='level of education', y='salary', 
            estimator=np.mean, ci='sd', hue='division');

plt.legend(bbox_to_anchor=(1.05,1))

# %% [markdown]
# ### More Categorical Plots

# %%
df = pd.read_csv('./data/StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.boxplot(data=df, y='math score');

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.boxplot(data=df, y='math score', x='test preparation course');

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.boxplot(data=df, y='reading score', x='test preparation course');

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.boxplot(data=df, y='math score', x='parental level of education');

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.boxplot(data=df, y='math score', x='parental level of education',
           hue='test preparation course')

plt.legend(bbox_to_anchor=(1.05,0.5));

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.boxplot(data=df, x='reading score', y='parental level of education',
           hue='test preparation course',
           palette='Set2')

plt.legend(bbox_to_anchor=(1.05,0.5));

# %% [markdown]
# **Violin Plot**

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.violinplot(data=df, x='reading score', y='parental level of education',
#            hue='test preparation course',
           palette='Set2', inner='stick');

# plt.legend(bbox_to_anchor=(1.25,0.5));

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.violinplot(data=df, x='reading score', y='parental level of education',
           hue='test preparation course',
           palette='Set2',
           split=True, inner='quartile')

plt.legend(bbox_to_anchor=(1.05,0.5));

# %%
plt.figure(figsize=(10,8), dpi=200)
sns.violinplot(data=df, x='reading score', y='parental level of education',
           palette='Set2', bw=0.1);

# %%
# advanced plots
plt.figure(figsize=(8,4), dpi=300)
sns.swarmplot(data=df, x='math score', size=2);

# %%
plt.figure(figsize=(8,4), dpi=300)
sns.swarmplot(data=df, x='math score', y='gender', size=2);

# %%
plt.figure(figsize=(8,4), dpi=300)
sns.swarmplot(data=df, x='math score', y='gender', size=2,
             hue='test preparation course', dodge=True)

plt.legend(bbox_to_anchor=(1.25, 0.5));

# %%
# advanced plots
sns.boxenplot(x='math score', y='test preparation course', data=df,
             hue='gender');

# %%
# more common plot is just the box plot:
sns.boxplot(x='math score', y='test preparation course', data=df,
             hue='gender');

# %% [markdown]
# ### Comparison Plots
#
# * jointplot(): histogram with scatterplot, 2D KDE shaded distribution
# * pairplot(): common in EDA of ML

# %% [markdown]
# #### Pair Plot
#
# * It gives a quick way to compare all numerical columns in a DataFrame
# * It automatically creates a histogram for each column and a scatterplot comparison between all possible combinations of columns
# * WARNING: this can be a bit CPU and RAM intensive

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.jointplot(data=df, x='math score', y='reading score');

# %%
sns.jointplot(data=df, x='math score', y='reading score',
             kind='hex');

# %%
sns.jointplot(data=df, x='math score', y='reading score',
             alpha=0.2);

# %%
sns.jointplot(data=df, x='math score', y='reading score',
             kind='hist');

# %%
sns.jointplot(data=df, x='math score', y='reading score',
             kind='kde', shade=True);

# %%
sns.jointplot(data=df, x='math score', y='reading score',
             hue='gender');

# %%
sns.pairplot(data=df, hue='gender');

# %%
sns.pairplot(data=df, hue='gender', diag_kind='hist');

# %%
sns.pairplot(data=df, hue='gender', corner=True);

# %%
sns.catplot(data=df, x='gender', y='math score', kind='box',
           row='lunch');
# similar to using hue to split by category

# %%
sns.catplot(data=df, x='gender', y='math score', kind='box',
           col='lunch');
# similar to using hue to split by category

# %%
sns.catplot(data=df, x='gender', y='math score', kind='box',
           col='lunch', row='test preparation course');
# try to limit this to 2x2 grid only

# %%
sns.pairplot(df);

# %%
# manually created your pair grid

g = sns.PairGrid(df, hue='gender')

g = g.map_upper(sns.scatterplot)

# g = g.map_diag(sns.histplot)
g = g.map_diag(sns.kdeplot)

g = g.map_lower(sns.kdeplot)

g = g.add_legend()

# %% [markdown]
# ### Matrix Plots
#
# * visual equivalent of displaying a pivot table
# * two main types: heatmap and clustermap

# %% [markdown]
# The heatmap() should ideally have all cells be in the same UNITS, so the color mapping will make sense across the entire DataFrame.

# %%
df = pd.read_csv('./data/country_table.csv')
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df = df.set_index("Countries")
df  # now this is a good candidate for heatmap()
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# ...

# %%
sns.heatmap(df);
# here, we include YEARS and RATE units (wrong!)

# %%
# plt.figure(figsize=(12,8), dpi=300)
sns.heatmap(df.drop('Life expectancy', axis=1), linewidth=0.5,
           annot=True);

# %%
# color mapping for colorblind people is important
sns.heatmap(df.drop('Life expectancy', axis=1), linewidth=0.5,
           annot=True,
           cmap='viridis');

# change the colorbar with the center=x keyword argument

# %%
sns.clustermap(df.drop('Life expectancy', axis=1), linewidth=0.5,
           annot=True,
           cmap='viridis');

# %%
sns.clustermap(df.drop('Life expectancy', axis=1), linewidth=0.5,
           annot=True,
           cmap='viridis',
           col_cluster=False);
