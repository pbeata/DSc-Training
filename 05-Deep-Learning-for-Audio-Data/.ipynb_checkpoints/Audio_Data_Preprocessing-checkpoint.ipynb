# %% [markdown]
# # Music Genre Classification - Data Preprocessing
#
# I preprocess an audio dataset and get it ready for music genre classification. Specifically, I implement code to batch process the Marsyas music dataset, in order to extract MFCCs and genre labels. I save the data in a json file, in a format that's convenient for retrieval when training the classifier.

# %%
import os
import math
import json
import librosa, librosa.display
# %config Completer.use_jedi = False

# %%
DATASET_PATH = ".\\data\\genre_dataset\\"
JSON_PATH = "data.json"
SAMPLE_RATE = 22050    # typical value for music data [Hz]
DURATION = 30          # measured in seconds [sec]
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %%
# function to save the MFCC
def save_mfcc(dataset_path, 
              json_path, 
              n_mfcc=13, 
              n_fft=2048, 
              hop_length=512, 
              num_segments=5):   # chop the tracks into smaller segments so we have more samples to work with
    
    # dictionary to store data
    data = {
        "mapping": [],   # "classical", "blues", etc.
        "mfcc": [],
        "labels": []     # numerical values 0, 1, 2, etc. for each genre
    }
    
    # set this variable
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    
    # we want to compute the mfcc at each hop length (round up though)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length)
    
    # loop through all the genres
    for i, (dir_path, dir_names, filenames) in enumerate(os.walk(dataset_path)):
        
        # ensure we're not at the root level
        if dir_path is not dataset_path:
            
            # save the semantic labels for each genre
            dir_path_components = dir_path.split("\\")   # genre/blues -> ["genre", "blues"]
            semantic_label = dir_path_components[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing Genre: {}".format(semantic_label))
            
            # process files for a specifc genre
            for f in filenames:
                
                # need file path to load the audio file
                file_path = os.path.join(dir_path, f)
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
                
                # process segments extracting MFCC and storing data
                for s in range(num_segments):
                    start_sample = num_samples_per_segment * s
                    finish_sample = start_sample + num_samples_per_segment
                    
                    # calculate the mfcc
                    mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],
                                                sr=sr,
                                                n_fft=n_fft,
                                                n_mfcc=n_mfcc,
                                                hop_length=hop_length)
                    
                    # get the transpose of mfcc
                    mfcc = mfcc.T
                    
                    # store the current segment's mfcc if it has expected length
                    if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i - 1)   # e.g., blues is 0, classical is 1, etc.
                        print("{}, segment: {}".format(file_path, s+1) )
    
    # save to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
# test with reduced dataset
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Processing Genre: blues
# .\data\genre_dataset\blues\blues.00000.wav, segment: 1
# .\data\genre_dataset\blues\blues.00000.wav, segment: 2
# .\data\genre_dataset\blues\blues.00000.wav, segment: 3
# .\data\genre_dataset\blues\blues.00000.wav, segment: 4
# .\data\genre_dataset\blues\blues.00000.wav, segment: 5
# .\data\genre_dataset\blues\blues.00000.wav, segment: 6
# .\data\genre_dataset\blues\blues.00000.wav, segment: 7
# .\data\genre_dataset\blues\blues.00000.wav, segment: 8
# .\data\genre_dataset\blues\blues.00000.wav, segment: 9
# .\data\genre_dataset\blues\blues.00000.wav, segment: 10
# .\data\genre_dataset\blues\blues.00001.wav, segment: 1
# .\data\genre_dataset\blues\blues.00001.wav, segment: 2
# .\data\genre_dataset\blues\blues.00001.wav, segment: 3
# .\data\genre_dataset\blues\blues.00001.wav, segment: 4
# .\data\genre_dataset\blues\blues.00001.wav, segment: 5
# .\data\genre_dataset\blues\blues.00001.wav, segment: 6
# .\data\genre_dataset\blues\blues.00001.wav, segment: 7
# .\data\genre_dataset\blues\blues.00001.wav, segment: 8
# .\data\genre_dataset\blues\blues.00001.wav, segment: 9
# .\data\genre_dataset\blues\blues.00001.wav, segment: 10
# .\data\genre_dataset\blues\blues.00002.wav, segment: 1
# .\data\genre_dataset\blues\blues.00002.wav, segment: 2
# .\data\genre_dataset\blues\blues.00002.wav, segment: 3
# .\data\genre_dataset\blues\blues.00002.wav, segment: 4
# .\data\genre_dataset\blues\blues.00002.wav, segment: 5
# .\data\genre_dataset\blues\blues.00002.wav, segment: 6
# .\data\genre_dataset\blues\blues.00002.wav, segment: 7
# .\data\genre_dataset\blues\blues.00002.wav, segment: 8
# .\data\genre_dataset\blues\blues.00002.wav, segment: 9
# .\data\genre_dataset\blues\blues.00002.wav, segment: 10
# .\data\genre_dataset\blues\blues.00003.wav, segment: 1
# .\data\genre_dataset\blues\blues.00003.wav, segment: 2
# .\data\genre_dataset\blues\blues.00003.wav, segment: 3
# .\data\genre_dataset\blues\blues.00003.wav, segment: 4
# .\data\genre_dataset\blues\blues.00003.wav, segment: 5
# .\data\genre_dataset\blues\blues.00003.wav, segment: 6
# .\data\genre_dataset\blues\blues.00003.wav, segment: 7
# .\data\genre_dataset\blues\blues.00003.wav, segment: 8
# .\data\genre_dataset\blues\blues.00003.wav, segment: 9
# .\data\genre_dataset\blues\blues.00003.wav, segment: 10
# .\data\genre_dataset\blues\blues.00004.wav, segment: 1
# .\data\genre_dataset\blues\blues.00004.wav, segment: 2
# .\data\genre_dataset\blues\blues.00004.wav, segment: 3
# .\data\genre_dataset\blues\blues.00004.wav, segment: 4
# .\data\genre_dataset\blues\blues.00004.wav, segment: 5
# .\data\genre_dataset\blues\blues.00004.wav, segment: 6
# .\data\genre_dataset\blues\blues.00004.wav, segment: 7
# .\data\genre_dataset\blues\blues.00004.wav, segment: 8
# .\data\genre_dataset\blues\blues.00004.wav, segment: 9
# .\data\genre_dataset\blues\blues.00004.wav, segment: 10
# .\data\genre_dataset\blues\blues.00005.wav, segment: 1
# .\data\genre_dataset\blues\blues.00005.wav, segment: 2
# .\data\genre_dataset\blues\blues.00005.wav, segment: 3
# .\data\genre_dataset\blues\blues.00005.wav, segment: 4
# .\data\genre_dataset\blues\blues.00005.wav, segment: 5
# .\data\genre_dataset\blues\blues.00005.wav, segment: 6
# .\data\genre_dataset\blues\blues.00005.wav, segment: 7
# .\data\genre_dataset\blues\blues.00005.wav, segment: 8
# .\data\genre_dataset\blues\blues.00005.wav, segment: 9
# .\data\genre_dataset\blues\blues.00005.wav, segment: 10
# .\data\genre_dataset\blues\blues.00006.wav, segment: 1
# .\data\genre_dataset\blues\blues.00006.wav, segment: 2
# .\data\genre_dataset\blues\blues.00006.wav, segment: 3
# .\data\genre_dataset\blues\blues.00006.wav, segment: 4
# .\data\genre_dataset\blues\blues.00006.wav, segment: 5
# .\data\genre_dataset\blues\blues.00006.wav, segment: 6
# .\data\genre_dataset\blues\blues.00006.wav, segment: 7
# .\data\genre_dataset\blues\blues.00006.wav, segment: 8
# .\data\genre_dataset\blues\blues.00006.wav, segment: 9
# .\data\genre_dataset\blues\blues.00006.wav, segment: 10
# .\data\genre_dataset\blues\blues.00007.wav, segment: 1
# .\data\genre_dataset\blues\blues.00007.wav, segment: 2
# .\data\genre_dataset\blues\blues.00007.wav, segment: 3
# .\data\genre_dataset\blues\blues.00007.wav, segment: 4
# .\data\genre_dataset\blues\blues.00007.wav, segment: 5
# .\data\genre_dataset\blues\blues.00007.wav, segment: 6
# .\data\genre_dataset\blues\blues.00007.wav, segment: 7
# .\data\genre_dataset\blues\blues.00007.wav, segment: 8
# .\data\genre_dataset\blues\blues.00007.wav, segment: 9
# .\data\genre_dataset\blues\blues.00007.wav, segment: 10
# .\data\genre_dataset\blues\blues.00008.wav, segment: 1
# .\data\genre_dataset\blues\blues.00008.wav, segment: 2
# .\data\genre_dataset\blues\blues.00008.wav, segment: 3
# .\data\genre_dataset\blues\blues.00008.wav, segment: 4
# .\data\genre_dataset\blues\blues.00008.wav, segment: 5
# .\data\genre_dataset\blues\blues.00008.wav, segment: 6
# .\data\genre_dataset\blues\blues.00008.wav, segment: 7
# .\data\genre_dataset\blues\blues.00008.wav, segment: 8
# .\data\genre_dataset\blues\blues.00008.wav, segment: 9
# .\data\genre_dataset\blues\blues.00008.wav, segment: 10
# .\data\genre_dataset\blues\blues.00009.wav, segment: 1
# .\data\genre_dataset\blues\blues.00009.wav, segment: 2
# .\data\genre_dataset\blues\blues.00009.wav, segment: 3
# .\data\genre_dataset\blues\blues.00009.wav, segment: 4
# .\data\genre_dataset\blues\blues.00009.wav, segment: 5
# .\data\genre_dataset\blues\blues.00009.wav, segment: 6
# .\data\genre_dataset\blues\blues.00009.wav, segment: 7
# .\data\genre_dataset\blues\blues.00009.wav, segment: 8
# .\data\genre_dataset\blues\blues.00009.wav, segment: 9
# .\data\genre_dataset\blues\blues.00009.wav, segment: 10
# .\data\genre_dataset\blues\blues.00010.wav, segment: 1
# .\data\genre_dataset\blues\blues.00010.wav, segment: 2
# .\data\genre_dataset\blues\blues.00010.wav, segment: 3
# .\data\genre_dataset\blues\blues.00010.wav, segment: 4
# .\data\genre_dataset\blues\blues.00010.wav, segment: 5
# .\data\genre_dataset\blues\blues.00010.wav, segment: 6
# .\data\genre_dataset\blues\blues.00010.wav, segment: 7
# .\data\genre_dataset\blues\blues.00010.wav, segment: 8
# .\data\genre_dataset\blues\blues.00010.wav, segment: 9
# .\data\genre_dataset\blues\blues.00010.wav, segment: 10
# .\data\genre_dataset\blues\blues.00011.wav, segment: 1
# .\data\genre_dataset\blues\blues.00011.wav, segment: 2
# .\data\genre_dataset\blues\blues.00011.wav, segment: 3
# .\data\genre_dataset\blues\blues.00011.wav, segment: 4
# .\data\genre_dataset\blues\blues.00011.wav, segment: 5
# .\data\genre_dataset\blues\blues.00011.wav, segment: 6
# .\data\genre_dataset\blues\blues.00011.wav, segment: 7
# .\data\genre_dataset\blues\blues.00011.wav, segment: 8
# .\data\genre_dataset\blues\blues.00011.wav, segment: 9
# .\data\genre_dataset\blues\blues.00011.wav, segment: 10
# .\data\genre_dataset\blues\blues.00012.wav, segment: 1
# .\data\genre_dataset\blues\blues.00012.wav, segment: 2
# .\data\genre_dataset\blues\blues.00012.wav, segment: 3
# .\data\genre_dataset\blues\blues.00012.wav, segment: 4
# .\data\genre_dataset\blues\blues.00012.wav, segment: 5
# .\data\genre_dataset\blues\blues.00012.wav, segment: 6
# .\data\genre_dataset\blues\blues.00012.wav, segment: 7
# .\data\genre_dataset\blues\blues.00012.wav, segment: 8
# .\data\genre_dataset\blues\blues.00012.wav, segment: 9
# .\data\genre_dataset\blues\blues.00012.wav, segment: 10
# .\data\genre_dataset\blues\blues.00013.wav, segment: 1
# .\data\genre_dataset\blues\blues.00013.wav, segment: 2
# .\data\genre_dataset\blues\blues.00013.wav, segment: 3
# .\data\genre_dataset\blues\blues.00013.wav, segment: 4
# .\data\genre_dataset\blues\blues.00013.wav, segment: 5
# .\data\genre_dataset\blues\blues.00013.wav, segment: 6
# .\data\genre_dataset\blues\blues.00013.wav, segment: 7
# .\data\genre_dataset\blues\blues.00013.wav, segment: 8
# .\data\genre_dataset\blues\blues.00013.wav, segment: 9
# .\data\genre_dataset\blues\blues.00013.wav, segment: 10
# .\data\genre_dataset\blues\blues.00014.wav, segment: 1
# .\data\genre_dataset\blues\blues.00014.wav, segment: 2
# .\data\genre_dataset\blues\blues.00014.wav, segment: 3
# .\data\genre_dataset\blues\blues.00014.wav, segment: 4
# .\data\genre_dataset\blues\blues.00014.wav, segment: 5
# .\data\genre_dataset\blues\blues.00014.wav, segment: 6
# .\data\genre_dataset\blues\blues.00014.wav, segment: 7
# .\data\genre_dataset\blues\blues.00014.wav, segment: 8
# .\data\genre_dataset\blues\blues.00014.wav, segment: 9
# .\data\genre_dataset\blues\blues.00014.wav, segment: 10
# .\data\genre_dataset\blues\blues.00015.wav, segment: 1
# .\data\genre_dataset\blues\blues.00015.wav, segment: 2
# .\data\genre_dataset\blues\blues.00015.wav, segment: 3
# .\data\genre_dataset\blues\blues.00015.wav, segment: 4
# .\data\genre_dataset\blues\blues.00015.wav, segment: 5
# .\data\genre_dataset\blues\blues.00015.wav, segment: 6
# .\data\genre_dataset\blues\blues.00015.wav, segment: 7
# .\data\genre_dataset\blues\blues.00015.wav, segment: 8
# .\data\genre_dataset\blues\blues.00015.wav, segment: 9
# .\data\genre_dataset\blues\blues.00015.wav, segment: 10
# .\data\genre_dataset\blues\blues.00016.wav, segment: 1
# .\data\genre_dataset\blues\blues.00016.wav, segment: 2
# .\data\genre_dataset\blues\blues.00016.wav, segment: 3
# .\data\genre_dataset\blues\blues.00016.wav, segment: 4
# .\data\genre_dataset\blues\blues.00016.wav, segment: 5
# .\data\genre_dataset\blues\blues.00016.wav, segment: 6
# .\data\genre_dataset\blues\blues.00016.wav, segment: 7
# .\data\genre_dataset\blues\blues.00016.wav, segment: 8
# .\data\genre_dataset\blues\blues.00016.wav, segment: 9
# .\data\genre_dataset\blues\blues.00016.wav, segment: 10
# .\data\genre_dataset\blues\blues.00017.wav, segment: 1
# .\data\genre_dataset\blues\blues.00017.wav, segment: 2
# .\data\genre_dataset\blues\blues.00017.wav, segment: 3
# .\data\genre_dataset\blues\blues.00017.wav, segment: 4
# .\data\genre_dataset\blues\blues.00017.wav, segment: 5
# .\data\genre_dataset\blues\blues.00017.wav, segment: 6
# .\data\genre_dataset\blues\blues.00017.wav, segment: 7
# .\data\genre_dataset\blues\blues.00017.wav, segment: 8
# .\data\genre_dataset\blues\blues.00017.wav, segment: 9
# .\data\genre_dataset\blues\blues.00017.wav, segment: 10
# .\data\genre_dataset\blues\blues.00018.wav, segment: 1
# .\data\genre_dataset\blues\blues.00018.wav, segment: 2
# .\data\genre_dataset\blues\blues.00018.wav, segment: 3
# .\data\genre_dataset\blues\blues.00018.wav, segment: 4
# .\data\genre_dataset\blues\blues.00018.wav, segment: 5
# .\data\genre_dataset\blues\blues.00018.wav, segment: 6
# .\data\genre_dataset\blues\blues.00018.wav, segment: 7
# .\data\genre_dataset\blues\blues.00018.wav, segment: 8
# .\data\genre_dataset\blues\blues.00018.wav, segment: 9
# .\data\genre_dataset\blues\blues.00018.wav, segment: 10
# .\data\genre_dataset\blues\blues.00019.wav, segment: 1
# .\data\genre_dataset\blues\blues.00019.wav, segment: 2
# .\data\genre_dataset\blues\blues.00019.wav, segment: 3
# .\data\genre_dataset\blues\blues.00019.wav, segment: 4
# .\data\genre_dataset\blues\blues.00019.wav, segment: 5
# .\data\genre_dataset\blues\blues.00019.wav, segment: 6
# .\data\genre_dataset\blues\blues.00019.wav, segment: 7
# .\data\genre_dataset\blues\blues.00019.wav, segment: 8
# .\data\genre_dataset\blues\blues.00019.wav, segment: 9
# .\data\genre_dataset\blues\blues.00019.wav, segment: 10
# .\data\genre_dataset\blues\blues.00020.wav, segment: 1
# .\data\genre_dataset\blues\blues.00020.wav, segment: 2
# .\data\genre_dataset\blues\blues.00020.wav, segment: 3
# .\data\genre_dataset\blues\blues.00020.wav, segment: 4
# .\data\genre_dataset\blues\blues.00020.wav, segment: 5
# .\data\genre_dataset\blues\blues.00020.wav, segment: 6
# .\data\genre_dataset\blues\blues.00020.wav, segment: 7
# .\data\genre_dataset\blues\blues.00020.wav, segment: 8
# .\data\genre_dataset\blues\blues.00020.wav, segment: 9
# .\data\genre_dataset\blues\blues.00020.wav, segment: 10
# .\data\genre_dataset\blues\blues.00021.wav, segment: 1
# .\data\genre_dataset\blues\blues.00021.wav, segment: 2
# .\data\genre_dataset\blues\blues.00021.wav, segment: 3
# .\data\genre_dataset\blues\blues.00021.wav, segment: 4
# .\data\genre_dataset\blues\blues.00021.wav, segment: 5
# .\data\genre_dataset\blues\blues.00021.wav, segment: 6
# .\data\genre_dataset\blues\blues.00021.wav, segment: 7
# .\data\genre_dataset\blues\blues.00021.wav, segment: 8
# .\data\genre_dataset\blues\blues.00021.wav, segment: 9
# .\data\genre_dataset\blues\blues.00021.wav, segment: 10
# .\data\genre_dataset\blues\blues.00022.wav, segment: 1
# .\data\genre_dataset\blues\blues.00022.wav, segment: 2
# .\data\genre_dataset\blues\blues.00022.wav, segment: 3
# .\data\genre_dataset\blues\blues.00022.wav, segment: 4
# .\data\genre_dataset\blues\blues.00022.wav, segment: 5
# .\data\genre_dataset\blues\blues.00022.wav, segment: 6
# .\data\genre_dataset\blues\blues.00022.wav, segment: 7
# .\data\genre_dataset\blues\blues.00022.wav, segment: 8
# .\data\genre_dataset\blues\blues.00022.wav, segment: 9
# .\data\genre_dataset\blues\blues.00022.wav, segment: 10
# .\data\genre_dataset\blues\blues.00023.wav, segment: 1
# .\data\genre_dataset\blues\blues.00023.wav, segment: 2
# .\data\genre_dataset\blues\blues.00023.wav, segment: 3
# .\data\genre_dataset\blues\blues.00023.wav, segment: 4
# .\data\genre_dataset\blues\blues.00023.wav, segment: 5
# .\data\genre_dataset\blues\blues.00023.wav, segment: 6
# .\data\genre_dataset\blues\blues.00023.wav, segment: 7
# .\data\genre_dataset\blues\blues.00023.wav, segment: 8
# .\data\genre_dataset\blues\blues.00023.wav, segment: 9
# .\data\genre_dataset\blues\blues.00023.wav, segment: 10
# .\data\genre_dataset\blues\blues.00024.wav, segment: 1
# .\data\genre_dataset\blues\blues.00024.wav, segment: 2
# .\data\genre_dataset\blues\blues.00024.wav, segment: 3
# .\data\genre_dataset\blues\blues.00024.wav, segment: 4
# .\data\genre_dataset\blues\blues.00024.wav, segment: 5
# .\data\genre_dataset\blues\blues.00024.wav, segment: 6
# .\data\genre_dataset\blues\blues.00024.wav, segment: 7
# .\data\genre_dataset\blues\blues.00024.wav, segment: 8
# .\data\genre_dataset\blues\blues.00024.wav, segment: 9
# .\data\genre_dataset\blues\blues.00024.wav, segment: 10
# .\data\genre_dataset\blues\blues.00025.wav, segment: 1
# .\data\genre_dataset\blues\blues.00025.wav, segment: 2
# .\data\genre_dataset\blues\blues.00025.wav, segment: 3
# .\data\genre_dataset\blues\blues.00025.wav, segment: 4
# .\data\genre_dataset\blues\blues.00025.wav, segment: 5
# .\data\genre_dataset\blues\blues.00025.wav, segment: 6
# .\data\genre_dataset\blues\blues.00025.wav, segment: 7
# .\data\genre_dataset\blues\blues.00025.wav, segment: 8
# .\data\genre_dataset\blues\blues.00025.wav, segment: 9
# .\data\genre_dataset\blues\blues.00025.wav, segment: 10
# .\data\genre_dataset\blues\blues.00026.wav, segment: 1
# .\data\genre_dataset\blues\blues.00026.wav, segment: 2
# .\data\genre_dataset\blues\blues.00026.wav, segment: 3
# .\data\genre_dataset\blues\blues.00026.wav, segment: 4
# .\data\genre_dataset\blues\blues.00026.wav, segment: 5
# .\data\genre_dataset\blues\blues.00026.wav, segment: 6
# .\data\genre_dataset\blues\blues.00026.wav, segment: 7
# .\data\genre_dataset\blues\blues.00026.wav, segment: 8
# .\data\genre_dataset\blues\blues.00026.wav, segment: 9
# .\data\genre_dataset\blues\blues.00026.wav, segment: 10
# .\data\genre_dataset\blues\blues.00027.wav, segment: 1
# .\data\genre_dataset\blues\blues.00027.wav, segment: 2
# .\data\genre_dataset\blues\blues.00027.wav, segment: 3
# .\data\genre_dataset\blues\blues.00027.wav, segment: 4
# .\data\genre_dataset\blues\blues.00027.wav, segment: 5
# .\data\genre_dataset\blues\blues.00027.wav, segment: 6
# .\data\genre_dataset\blues\blues.00027.wav, segment: 7
# .\data\genre_dataset\blues\blues.00027.wav, segment: 8
# .\data\genre_dataset\blues\blues.00027.wav, segment: 9
# .\data\genre_dataset\blues\blues.00027.wav, segment: 10
# .\data\genre_dataset\blues\blues.00028.wav, segment: 1
# .\data\genre_dataset\blues\blues.00028.wav, segment: 2
# .\data\genre_dataset\blues\blues.00028.wav, segment: 3
# .\data\genre_dataset\blues\blues.00028.wav, segment: 4
# .\data\genre_dataset\blues\blues.00028.wav, segment: 5
# .\data\genre_dataset\blues\blues.00028.wav, segment: 6
# .\data\genre_dataset\blues\blues.00028.wav, segment: 7
# .\data\genre_dataset\blues\blues.00028.wav, segment: 8
# .\data\genre_dataset\blues\blues.00028.wav, segment: 9
# .\data\genre_dataset\blues\blues.00028.wav, segment: 10
# .\data\genre_dataset\blues\blues.00029.wav, segment: 1
# .\data\genre_dataset\blues\blues.00029.wav, segment: 2
# .\data\genre_dataset\blues\blues.00029.wav, segment: 3
# .\data\genre_dataset\blues\blues.00029.wav, segment: 4
# .\data\genre_dataset\blues\blues.00029.wav, segment: 5
# .\data\genre_dataset\blues\blues.00029.wav, segment: 6
# .\data\genre_dataset\blues\blues.00029.wav, segment: 7
# .\data\genre_dataset\blues\blues.00029.wav, segment: 8
# .\data\genre_dataset\blues\blues.00029.wav, segment: 9
# .\data\genre_dataset\blues\blues.00029.wav, segment: 10
# .\data\genre_dataset\blues\blues.00030.wav, segment: 1
# .\data\genre_dataset\blues\blues.00030.wav, segment: 2
# .\data\genre_dataset\blues\blues.00030.wav, segment: 3
# .\data\genre_dataset\blues\blues.00030.wav, segment: 4
# .\data\genre_dataset\blues\blues.00030.wav, segment: 5
# .\data\genre_dataset\blues\blues.00030.wav, segment: 6
# .\data\genre_dataset\blues\blues.00030.wav, segment: 7
# .\data\genre_dataset\blues\blues.00030.wav, segment: 8
# .\data\genre_dataset\blues\blues.00030.wav, segment: 9
# .\data\genre_dataset\blues\blues.00030.wav, segment: 10
# .\data\genre_dataset\blues\blues.00031.wav, segment: 1
# .\data\genre_dataset\blues\blues.00031.wav, segment: 2
# .\data\genre_dataset\blues\blues.00031.wav, segment: 3
# .\data\genre_dataset\blues\blues.00031.wav, segment: 4
# .\data\genre_dataset\blues\blues.00031.wav, segment: 5
# .\data\genre_dataset\blues\blues.00031.wav, segment: 6
# .\data\genre_dataset\blues\blues.00031.wav, segment: 7
# .\data\genre_dataset\blues\blues.00031.wav, segment: 8
# .\data\genre_dataset\blues\blues.00031.wav, segment: 9
# .\data\genre_dataset\blues\blues.00031.wav, segment: 10
# .\data\genre_dataset\blues\blues.00032.wav, segment: 1
# .\data\genre_dataset\blues\blues.00032.wav, segment: 2
# .\data\genre_dataset\blues\blues.00032.wav, segment: 3
# .\data\genre_dataset\blues\blues.00032.wav, segment: 4
# .\data\genre_dataset\blues\blues.00032.wav, segment: 5
# .\data\genre_dataset\blues\blues.00032.wav, segment: 6
# .\data\genre_dataset\blues\blues.00032.wav, segment: 7
# .\data\genre_dataset\blues\blues.00032.wav, segment: 8
# .\data\genre_dataset\blues\blues.00032.wav, segment: 9
# .\data\genre_dataset\blues\blues.00032.wav, segment: 10
# .\data\genre_dataset\blues\blues.00033.wav, segment: 1
# .\data\genre_dataset\blues\blues.00033.wav, segment: 2
# .\data\genre_dataset\blues\blues.00033.wav, segment: 3
# .\data\genre_dataset\blues\blues.00033.wav, segment: 4
# .\data\genre_dataset\blues\blues.00033.wav, segment: 5
# .\data\genre_dataset\blues\blues.00033.wav, segment: 6
# .\data\genre_dataset\blues\blues.00033.wav, segment: 7
# .\data\genre_dataset\blues\blues.00033.wav, segment: 8
# .\data\genre_dataset\blues\blues.00033.wav, segment: 9
# .\data\genre_dataset\blues\blues.00033.wav, segment: 10
# .\data\genre_dataset\blues\blues.00034.wav, segment: 1
# .\data\genre_dataset\blues\blues.00034.wav, segment: 2
# .\data\genre_dataset\blues\blues.00034.wav, segment: 3
# .\data\genre_dataset\blues\blues.00034.wav, segment: 4
# .\data\genre_dataset\blues\blues.00034.wav, segment: 5
# .\data\genre_dataset\blues\blues.00034.wav, segment: 6
# .\data\genre_dataset\blues\blues.00034.wav, segment: 7
# .\data\genre_dataset\blues\blues.00034.wav, segment: 8
# .\data\genre_dataset\blues\blues.00034.wav, segment: 9
# .\data\genre_dataset\blues\blues.00034.wav, segment: 10
# .\data\genre_dataset\blues\blues.00035.wav, segment: 1
# .\data\genre_dataset\blues\blues.00035.wav, segment: 2
# .\data\genre_dataset\blues\blues.00035.wav, segment: 3
# .\data\genre_dataset\blues\blues.00035.wav, segment: 4
# .\data\genre_dataset\blues\blues.00035.wav, segment: 5
# .\data\genre_dataset\blues\blues.00035.wav, segment: 6
# .\data\genre_dataset\blues\blues.00035.wav, segment: 7
# .\data\genre_dataset\blues\blues.00035.wav, segment: 8
# .\data\genre_dataset\blues\blues.00035.wav, segment: 9
# .\data\genre_dataset\blues\blues.00035.wav, segment: 10
# .\data\genre_dataset\blues\blues.00036.wav, segment: 1
# .\data\genre_dataset\blues\blues.00036.wav, segment: 2
# .\data\genre_dataset\blues\blues.00036.wav, segment: 3
# .\data\genre_dataset\blues\blues.00036.wav, segment: 4
# .\data\genre_dataset\blues\blues.00036.wav, segment: 5
# .\data\genre_dataset\blues\blues.00036.wav, segment: 6
# .\data\genre_dataset\blues\blues.00036.wav, segment: 7
# .\data\genre_dataset\blues\blues.00036.wav, segment: 8
# .\data\genre_dataset\blues\blues.00036.wav, segment: 9
# .\data\genre_dataset\blues\blues.00036.wav, segment: 10
# .\data\genre_dataset\blues\blues.00037.wav, segment: 1
# .\data\genre_dataset\blues\blues.00037.wav, segment: 2
# .\data\genre_dataset\blues\blues.00037.wav, segment: 3
# .\data\genre_dataset\blues\blues.00037.wav, segment: 4
# .\data\genre_dataset\blues\blues.00037.wav, segment: 5
# .\data\genre_dataset\blues\blues.00037.wav, segment: 6
# .\data\genre_dataset\blues\blues.00037.wav, segment: 7
# .\data\genre_dataset\blues\blues.00037.wav, segment: 8
# .\data\genre_dataset\blues\blues.00037.wav, segment: 9
# .\data\genre_dataset\blues\blues.00037.wav, segment: 10
# .\data\genre_dataset\blues\blues.00038.wav, segment: 1
# .\data\genre_dataset\blues\blues.00038.wav, segment: 2
# .\data\genre_dataset\blues\blues.00038.wav, segment: 3
# .\data\genre_dataset\blues\blues.00038.wav, segment: 4
# .\data\genre_dataset\blues\blues.00038.wav, segment: 5
# .\data\genre_dataset\blues\blues.00038.wav, segment: 6
# .\data\genre_dataset\blues\blues.00038.wav, segment: 7
# .\data\genre_dataset\blues\blues.00038.wav, segment: 8
# .\data\genre_dataset\blues\blues.00038.wav, segment: 9
# .\data\genre_dataset\blues\blues.00038.wav, segment: 10
# .\data\genre_dataset\blues\blues.00039.wav, segment: 1
# .\data\genre_dataset\blues\blues.00039.wav, segment: 2
# .\data\genre_dataset\blues\blues.00039.wav, segment: 3
# .\data\genre_dataset\blues\blues.00039.wav, segment: 4
# .\data\genre_dataset\blues\blues.00039.wav, segment: 5
# .\data\genre_dataset\blues\blues.00039.wav, segment: 6
# .\data\genre_dataset\blues\blues.00039.wav, segment: 7
# .\data\genre_dataset\blues\blues.00039.wav, segment: 8
# .\data\genre_dataset\blues\blues.00039.wav, segment: 9
# .\data\genre_dataset\blues\blues.00039.wav, segment: 10
# .\data\genre_dataset\blues\blues.00040.wav, segment: 1
# .\data\genre_dataset\blues\blues.00040.wav, segment: 2
# .\data\genre_dataset\blues\blues.00040.wav, segment: 3
# .\data\genre_dataset\blues\blues.00040.wav, segment: 4
# .\data\genre_dataset\blues\blues.00040.wav, segment: 5
# .\data\genre_dataset\blues\blues.00040.wav, segment: 6
# .\data\genre_dataset\blues\blues.00040.wav, segment: 7
# .\data\genre_dataset\blues\blues.00040.wav, segment: 8
# .\data\genre_dataset\blues\blues.00040.wav, segment: 9
# .\data\genre_dataset\blues\blues.00040.wav, segment: 10
# .\data\genre_dataset\blues\blues.00041.wav, segment: 1
# .\data\genre_dataset\blues\blues.00041.wav, segment: 2
# .\data\genre_dataset\blues\blues.00041.wav, segment: 3
# .\data\genre_dataset\blues\blues.00041.wav, segment: 4
# .\data\genre_dataset\blues\blues.00041.wav, segment: 5
# .\data\genre_dataset\blues\blues.00041.wav, segment: 6
# .\data\genre_dataset\blues\blues.00041.wav, segment: 7
# .\data\genre_dataset\blues\blues.00041.wav, segment: 8
# .\data\genre_dataset\blues\blues.00041.wav, segment: 9
# .\data\genre_dataset\blues\blues.00041.wav, segment: 10
# .\data\genre_dataset\blues\blues.00042.wav, segment: 1
# .\data\genre_dataset\blues\blues.00042.wav, segment: 2
# .\data\genre_dataset\blues\blues.00042.wav, segment: 3
# .\data\genre_dataset\blues\blues.00042.wav, segment: 4
# .\data\genre_dataset\blues\blues.00042.wav, segment: 5
# .\data\genre_dataset\blues\blues.00042.wav, segment: 6
# .\data\genre_dataset\blues\blues.00042.wav, segment: 7
# .\data\genre_dataset\blues\blues.00042.wav, segment: 8
# .\data\genre_dataset\blues\blues.00042.wav, segment: 9
# .\data\genre_dataset\blues\blues.00042.wav, segment: 10
# .\data\genre_dataset\blues\blues.00043.wav, segment: 1
# .\data\genre_dataset\blues\blues.00043.wav, segment: 2
# .\data\genre_dataset\blues\blues.00043.wav, segment: 3
# .\data\genre_dataset\blues\blues.00043.wav, segment: 4
# .\data\genre_dataset\blues\blues.00043.wav, segment: 5
# .\data\genre_dataset\blues\blues.00043.wav, segment: 6
# .\data\genre_dataset\blues\blues.00043.wav, segment: 7
# .\data\genre_dataset\blues\blues.00043.wav, segment: 8
# .\data\genre_dataset\blues\blues.00043.wav, segment: 9
# .\data\genre_dataset\blues\blues.00043.wav, segment: 10
# .\data\genre_dataset\blues\blues.00044.wav, segment: 1
# .\data\genre_dataset\blues\blues.00044.wav, segment: 2
# .\data\genre_dataset\blues\blues.00044.wav, segment: 3
# .\data\genre_dataset\blues\blues.00044.wav, segment: 4
# .\data\genre_dataset\blues\blues.00044.wav, segment: 5
# .\data\genre_dataset\blues\blues.00044.wav, segment: 6
# .\data\genre_dataset\blues\blues.00044.wav, segment: 7
# .\data\genre_dataset\blues\blues.00044.wav, segment: 8
# .\data\genre_dataset\blues\blues.00044.wav, segment: 9
# .\data\genre_dataset\blues\blues.00044.wav, segment: 10
# .\data\genre_dataset\blues\blues.00045.wav, segment: 1
# .\data\genre_dataset\blues\blues.00045.wav, segment: 2
# .\data\genre_dataset\blues\blues.00045.wav, segment: 3
# .\data\genre_dataset\blues\blues.00045.wav, segment: 4
# .\data\genre_dataset\blues\blues.00045.wav, segment: 5
# .\data\genre_dataset\blues\blues.00045.wav, segment: 6
# .\data\genre_dataset\blues\blues.00045.wav, segment: 7
# .\data\genre_dataset\blues\blues.00045.wav, segment: 8
# .\data\genre_dataset\blues\blues.00045.wav, segment: 9
# .\data\genre_dataset\blues\blues.00045.wav, segment: 10
# .\data\genre_dataset\blues\blues.00046.wav, segment: 1
# .\data\genre_dataset\blues\blues.00046.wav, segment: 2
# .\data\genre_dataset\blues\blues.00046.wav, segment: 3
# .\data\genre_dataset\blues\blues.00046.wav, segment: 4
# .\data\genre_dataset\blues\blues.00046.wav, segment: 5
# .\data\genre_dataset\blues\blues.00046.wav, segment: 6
# .\data\genre_dataset\blues\blues.00046.wav, segment: 7
# .\data\genre_dataset\blues\blues.00046.wav, segment: 8
# .\data\genre_dataset\blues\blues.00046.wav, segment: 9
# .\data\genre_dataset\blues\blues.00046.wav, segment: 10
# .\data\genre_dataset\blues\blues.00047.wav, segment: 1
# .\data\genre_dataset\blues\blues.00047.wav, segment: 2
# .\data\genre_dataset\blues\blues.00047.wav, segment: 3
# .\data\genre_dataset\blues\blues.00047.wav, segment: 4
# .\data\genre_dataset\blues\blues.00047.wav, segment: 5
# .\data\genre_dataset\blues\blues.00047.wav, segment: 6
# .\data\genre_dataset\blues\blues.00047.wav, segment: 7
# .\data\genre_dataset\blues\blues.00047.wav, segment: 8
# .\data\genre_dataset\blues\blues.00047.wav, segment: 9
# .\data\genre_dataset\blues\blues.00047.wav, segment: 10
# .\data\genre_dataset\blues\blues.00048.wav, segment: 1
# .\data\genre_dataset\blues\blues.00048.wav, segment: 2
# .\data\genre_dataset\blues\blues.00048.wav, segment: 3
# .\data\genre_dataset\blues\blues.00048.wav, segment: 4
# .\data\genre_dataset\blues\blues.00048.wav, segment: 5
# .\data\genre_dataset\blues\blues.00048.wav, segment: 6
# .\data\genre_dataset\blues\blues.00048.wav, segment: 7
# .\data\genre_dataset\blues\blues.00048.wav, segment: 8
# .\data\genre_dataset\blues\blues.00048.wav, segment: 9
# .\data\genre_dataset\blues\blues.00048.wav, segment: 10
# .\data\genre_dataset\blues\blues.00049.wav, segment: 1
# .\data\genre_dataset\blues\blues.00049.wav, segment: 2
# .\data\genre_dataset\blues\blues.00049.wav, segment: 3
# .\data\genre_dataset\blues\blues.00049.wav, segment: 4
# .\data\genre_dataset\blues\blues.00049.wav, segment: 5
# .\data\genre_dataset\blues\blues.00049.wav, segment: 6
# .\data\genre_dataset\blues\blues.00049.wav, segment: 7
# .\data\genre_dataset\blues\blues.00049.wav, segment: 8
# .\data\genre_dataset\blues\blues.00049.wav, segment: 9
# .\data\genre_dataset\blues\blues.00049.wav, segment: 10
# .\data\genre_dataset\blues\blues.00050.wav, segment: 1
# .\data\genre_dataset\blues\blues.00050.wav, segment: 2
# .\data\genre_dataset\blues\blues.00050.wav, segment: 3
# .\data\genre_dataset\blues\blues.00050.wav, segment: 4
# .\data\genre_dataset\blues\blues.00050.wav, segment: 5
# .\data\genre_dataset\blues\blues.00050.wav, segment: 6
# .\data\genre_dataset\blues\blues.00050.wav, segment: 7
# .\data\genre_dataset\blues\blues.00050.wav, segment: 8
# .\data\genre_dataset\blues\blues.00050.wav, segment: 9
# .\data\genre_dataset\blues\blues.00050.wav, segment: 10
# .\data\genre_dataset\blues\blues.00051.wav, segment: 1
# .\data\genre_dataset\blues\blues.00051.wav, segment: 2
# .\data\genre_dataset\blues\blues.00051.wav, segment: 3
# .\data\genre_dataset\blues\blues.00051.wav, segment: 4
# .\data\genre_dataset\blues\blues.00051.wav, segment: 5
# .\data\genre_dataset\blues\blues.00051.wav, segment: 6
# .\data\genre_dataset\blues\blues.00051.wav, segment: 7
# .\data\genre_dataset\blues\blues.00051.wav, segment: 8
# .\data\genre_dataset\blues\blues.00051.wav, segment: 9
# .\data\genre_dataset\blues\blues.00051.wav, segment: 10
# .\data\genre_dataset\blues\blues.00052.wav, segment: 1
# .\data\genre_dataset\blues\blues.00052.wav, segment: 2
# .\data\genre_dataset\blues\blues.00052.wav, segment: 3
# .\data\genre_dataset\blues\blues.00052.wav, segment: 4
# .\data\genre_dataset\blues\blues.00052.wav, segment: 5
# .\data\genre_dataset\blues\blues.00052.wav, segment: 6
# .\data\genre_dataset\blues\blues.00052.wav, segment: 7
# .\data\genre_dataset\blues\blues.00052.wav, segment: 8
# .\data\genre_dataset\blues\blues.00052.wav, segment: 9
# .\data\genre_dataset\blues\blues.00052.wav, segment: 10
# .\data\genre_dataset\blues\blues.00053.wav, segment: 1
# .\data\genre_dataset\blues\blues.00053.wav, segment: 2
# .\data\genre_dataset\blues\blues.00053.wav, segment: 3
# .\data\genre_dataset\blues\blues.00053.wav, segment: 4
# .\data\genre_dataset\blues\blues.00053.wav, segment: 5
# .\data\genre_dataset\blues\blues.00053.wav, segment: 6
# .\data\genre_dataset\blues\blues.00053.wav, segment: 7
# .\data\genre_dataset\blues\blues.00053.wav, segment: 8
# .\data\genre_dataset\blues\blues.00053.wav, segment: 9
# .\data\genre_dataset\blues\blues.00053.wav, segment: 10
# .\data\genre_dataset\blues\blues.00054.wav, segment: 1
# .\data\genre_dataset\blues\blues.00054.wav, segment: 2
# .\data\genre_dataset\blues\blues.00054.wav, segment: 3
# .\data\genre_dataset\blues\blues.00054.wav, segment: 4
# .\data\genre_dataset\blues\blues.00054.wav, segment: 5
# .\data\genre_dataset\blues\blues.00054.wav, segment: 6
# .\data\genre_dataset\blues\blues.00054.wav, segment: 7
# .\data\genre_dataset\blues\blues.00054.wav, segment: 8
# .\data\genre_dataset\blues\blues.00054.wav, segment: 9
# .\data\genre_dataset\blues\blues.00054.wav, segment: 10
# .\data\genre_dataset\blues\blues.00055.wav, segment: 1
# .\data\genre_dataset\blues\blues.00055.wav, segment: 2
# .\data\genre_dataset\blues\blues.00055.wav, segment: 3
# .\data\genre_dataset\blues\blues.00055.wav, segment: 4
# .\data\genre_dataset\blues\blues.00055.wav, segment: 5
# .\data\genre_dataset\blues\blues.00055.wav, segment: 6
# .\data\genre_dataset\blues\blues.00055.wav, segment: 7
# .\data\genre_dataset\blues\blues.00055.wav, segment: 8
# .\data\genre_dataset\blues\blues.00055.wav, segment: 9
# .\data\genre_dataset\blues\blues.00055.wav, segment: 10
# .\data\genre_dataset\blues\blues.00056.wav, segment: 1
# .\data\genre_dataset\blues\blues.00056.wav, segment: 2
# .\data\genre_dataset\blues\blues.00056.wav, segment: 3
# .\data\genre_dataset\blues\blues.00056.wav, segment: 4
# .\data\genre_dataset\blues\blues.00056.wav, segment: 5
# .\data\genre_dataset\blues\blues.00056.wav, segment: 6
# .\data\genre_dataset\blues\blues.00056.wav, segment: 7
# .\data\genre_dataset\blues\blues.00056.wav, segment: 8
# .\data\genre_dataset\blues\blues.00056.wav, segment: 9
# .\data\genre_dataset\blues\blues.00056.wav, segment: 10
# .\data\genre_dataset\blues\blues.00057.wav, segment: 1
# .\data\genre_dataset\blues\blues.00057.wav, segment: 2
# .\data\genre_dataset\blues\blues.00057.wav, segment: 3
# .\data\genre_dataset\blues\blues.00057.wav, segment: 4
# .\data\genre_dataset\blues\blues.00057.wav, segment: 5
# .\data\genre_dataset\blues\blues.00057.wav, segment: 6
# .\data\genre_dataset\blues\blues.00057.wav, segment: 7
# .\data\genre_dataset\blues\blues.00057.wav, segment: 8
# .\data\genre_dataset\blues\blues.00057.wav, segment: 9
# .\data\genre_dataset\blues\blues.00057.wav, segment: 10
# .\data\genre_dataset\blues\blues.00058.wav, segment: 1
# .\data\genre_dataset\blues\blues.00058.wav, segment: 2
# .\data\genre_dataset\blues\blues.00058.wav, segment: 3
# .\data\genre_dataset\blues\blues.00058.wav, segment: 4
# .\data\genre_dataset\blues\blues.00058.wav, segment: 5
# .\data\genre_dataset\blues\blues.00058.wav, segment: 6
# .\data\genre_dataset\blues\blues.00058.wav, segment: 7
# .\data\genre_dataset\blues\blues.00058.wav, segment: 8
# .\data\genre_dataset\blues\blues.00058.wav, segment: 9
# .\data\genre_dataset\blues\blues.00058.wav, segment: 10
# .\data\genre_dataset\blues\blues.00059.wav, segment: 1
# .\data\genre_dataset\blues\blues.00059.wav, segment: 2
# .\data\genre_dataset\blues\blues.00059.wav, segment: 3
# .\data\genre_dataset\blues\blues.00059.wav, segment: 4
# .\data\genre_dataset\blues\blues.00059.wav, segment: 5
# .\data\genre_dataset\blues\blues.00059.wav, segment: 6
# .\data\genre_dataset\blues\blues.00059.wav, segment: 7
# .\data\genre_dataset\blues\blues.00059.wav, segment: 8
# .\data\genre_dataset\blues\blues.00059.wav, segment: 9
# .\data\genre_dataset\blues\blues.00059.wav, segment: 10
# .\data\genre_dataset\blues\blues.00060.wav, segment: 1
# .\data\genre_dataset\blues\blues.00060.wav, segment: 2
# .\data\genre_dataset\blues\blues.00060.wav, segment: 3
# .\data\genre_dataset\blues\blues.00060.wav, segment: 4
# .\data\genre_dataset\blues\blues.00060.wav, segment: 5
# .\data\genre_dataset\blues\blues.00060.wav, segment: 6
# .\data\genre_dataset\blues\blues.00060.wav, segment: 7
# .\data\genre_dataset\blues\blues.00060.wav, segment: 8
# .\data\genre_dataset\blues\blues.00060.wav, segment: 9
# .\data\genre_dataset\blues\blues.00060.wav, segment: 10
# .\data\genre_dataset\blues\blues.00061.wav, segment: 1
# .\data\genre_dataset\blues\blues.00061.wav, segment: 2
# .\data\genre_dataset\blues\blues.00061.wav, segment: 3
# .\data\genre_dataset\blues\blues.00061.wav, segment: 4
# .\data\genre_dataset\blues\blues.00061.wav, segment: 5
# .\data\genre_dataset\blues\blues.00061.wav, segment: 6
# .\data\genre_dataset\blues\blues.00061.wav, segment: 7
# .\data\genre_dataset\blues\blues.00061.wav, segment: 8
# .\data\genre_dataset\blues\blues.00061.wav, segment: 9
# .\data\genre_dataset\blues\blues.00061.wav, segment: 10
# .\data\genre_dataset\blues\blues.00062.wav, segment: 1
# .\data\genre_dataset\blues\blues.00062.wav, segment: 2
# .\data\genre_dataset\blues\blues.00062.wav, segment: 3
# .\data\genre_dataset\blues\blues.00062.wav, segment: 4
# .\data\genre_dataset\blues\blues.00062.wav, segment: 5
# .\data\genre_dataset\blues\blues.00062.wav, segment: 6
# .\data\genre_dataset\blues\blues.00062.wav, segment: 7
# .\data\genre_dataset\blues\blues.00062.wav, segment: 8
# .\data\genre_dataset\blues\blues.00062.wav, segment: 9
# .\data\genre_dataset\blues\blues.00062.wav, segment: 10
# .\data\genre_dataset\blues\blues.00063.wav, segment: 1
# .\data\genre_dataset\blues\blues.00063.wav, segment: 2
# .\data\genre_dataset\blues\blues.00063.wav, segment: 3
# .\data\genre_dataset\blues\blues.00063.wav, segment: 4
# .\data\genre_dataset\blues\blues.00063.wav, segment: 5
# .\data\genre_dataset\blues\blues.00063.wav, segment: 6
# .\data\genre_dataset\blues\blues.00063.wav, segment: 7
# .\data\genre_dataset\blues\blues.00063.wav, segment: 8
# .\data\genre_dataset\blues\blues.00063.wav, segment: 9
# .\data\genre_dataset\blues\blues.00063.wav, segment: 10
# .\data\genre_dataset\blues\blues.00064.wav, segment: 1
# .\data\genre_dataset\blues\blues.00064.wav, segment: 2
# .\data\genre_dataset\blues\blues.00064.wav, segment: 3
# .\data\genre_dataset\blues\blues.00064.wav, segment: 4
# .\data\genre_dataset\blues\blues.00064.wav, segment: 5
# .\data\genre_dataset\blues\blues.00064.wav, segment: 6
# .\data\genre_dataset\blues\blues.00064.wav, segment: 7
# .\data\genre_dataset\blues\blues.00064.wav, segment: 8
# .\data\genre_dataset\blues\blues.00064.wav, segment: 9
# .\data\genre_dataset\blues\blues.00064.wav, segment: 10
# .\data\genre_dataset\blues\blues.00065.wav, segment: 1
# .\data\genre_dataset\blues\blues.00065.wav, segment: 2
# .\data\genre_dataset\blues\blues.00065.wav, segment: 3
# .\data\genre_dataset\blues\blues.00065.wav, segment: 4
# .\data\genre_dataset\blues\blues.00065.wav, segment: 5
# .\data\genre_dataset\blues\blues.00065.wav, segment: 6
# .\data\genre_dataset\blues\blues.00065.wav, segment: 7
# .\data\genre_dataset\blues\blues.00065.wav, segment: 8
# .\data\genre_dataset\blues\blues.00065.wav, segment: 9
# .\data\genre_dataset\blues\blues.00065.wav, segment: 10
# .\data\genre_dataset\blues\blues.00066.wav, segment: 1
# .\data\genre_dataset\blues\blues.00066.wav, segment: 2
# .\data\genre_dataset\blues\blues.00066.wav, segment: 3
# .\data\genre_dataset\blues\blues.00066.wav, segment: 4
# .\data\genre_dataset\blues\blues.00066.wav, segment: 5
# .\data\genre_dataset\blues\blues.00066.wav, segment: 6
# .\data\genre_dataset\blues\blues.00066.wav, segment: 7
# .\data\genre_dataset\blues\blues.00066.wav, segment: 8
# .\data\genre_dataset\blues\blues.00066.wav, segment: 9
# .\data\genre_dataset\blues\blues.00066.wav, segment: 10
# .\data\genre_dataset\blues\blues.00067.wav, segment: 1
# .\data\genre_dataset\blues\blues.00067.wav, segment: 2
# .\data\genre_dataset\blues\blues.00067.wav, segment: 3
# .\data\genre_dataset\blues\blues.00067.wav, segment: 4
# .\data\genre_dataset\blues\blues.00067.wav, segment: 5
# .\data\genre_dataset\blues\blues.00067.wav, segment: 6
# .\data\genre_dataset\blues\blues.00067.wav, segment: 7
# .\data\genre_dataset\blues\blues.00067.wav, segment: 8
# .\data\genre_dataset\blues\blues.00067.wav, segment: 9
# .\data\genre_dataset\blues\blues.00067.wav, segment: 10
# .\data\genre_dataset\blues\blues.00068.wav, segment: 1
# .\data\genre_dataset\blues\blues.00068.wav, segment: 2
# .\data\genre_dataset\blues\blues.00068.wav, segment: 3
# .\data\genre_dataset\blues\blues.00068.wav, segment: 4
# .\data\genre_dataset\blues\blues.00068.wav, segment: 5
# .\data\genre_dataset\blues\blues.00068.wav, segment: 6
# .\data\genre_dataset\blues\blues.00068.wav, segment: 7
# .\data\genre_dataset\blues\blues.00068.wav, segment: 8
# .\data\genre_dataset\blues\blues.00068.wav, segment: 9
# .\data\genre_dataset\blues\blues.00068.wav, segment: 10
# .\data\genre_dataset\blues\blues.00069.wav, segment: 1
# .\data\genre_dataset\blues\blues.00069.wav, segment: 2
# .\data\genre_dataset\blues\blues.00069.wav, segment: 3
# .\data\genre_dataset\blues\blues.00069.wav, segment: 4
# .\data\genre_dataset\blues\blues.00069.wav, segment: 5
# .\data\genre_dataset\blues\blues.00069.wav, segment: 6
# .\data\genre_dataset\blues\blues.00069.wav, segment: 7
# .\data\genre_dataset\blues\blues.00069.wav, segment: 8
# .\data\genre_dataset\blues\blues.00069.wav, segment: 9
# .\data\genre_dataset\blues\blues.00069.wav, segment: 10
# .\data\genre_dataset\blues\blues.00070.wav, segment: 1
# .\data\genre_dataset\blues\blues.00070.wav, segment: 2
# .\data\genre_dataset\blues\blues.00070.wav, segment: 3
# .\data\genre_dataset\blues\blues.00070.wav, segment: 4
# .\data\genre_dataset\blues\blues.00070.wav, segment: 5
# .\data\genre_dataset\blues\blues.00070.wav, segment: 6
# .\data\genre_dataset\blues\blues.00070.wav, segment: 7
# .\data\genre_dataset\blues\blues.00070.wav, segment: 8
# .\data\genre_dataset\blues\blues.00070.wav, segment: 9
# .\data\genre_dataset\blues\blues.00070.wav, segment: 10
# .\data\genre_dataset\blues\blues.00071.wav, segment: 1
# .\data\genre_dataset\blues\blues.00071.wav, segment: 2
# .\data\genre_dataset\blues\blues.00071.wav, segment: 3
# .\data\genre_dataset\blues\blues.00071.wav, segment: 4
# .\data\genre_dataset\blues\blues.00071.wav, segment: 5
# .\data\genre_dataset\blues\blues.00071.wav, segment: 6
# .\data\genre_dataset\blues\blues.00071.wav, segment: 7
# .\data\genre_dataset\blues\blues.00071.wav, segment: 8
# .\data\genre_dataset\blues\blues.00071.wav, segment: 9
# .\data\genre_dataset\blues\blues.00071.wav, segment: 10
# .\data\genre_dataset\blues\blues.00072.wav, segment: 1
# .\data\genre_dataset\blues\blues.00072.wav, segment: 2
# .\data\genre_dataset\blues\blues.00072.wav, segment: 3
# .\data\genre_dataset\blues\blues.00072.wav, segment: 4
# .\data\genre_dataset\blues\blues.00072.wav, segment: 5
# .\data\genre_dataset\blues\blues.00072.wav, segment: 6
# .\data\genre_dataset\blues\blues.00072.wav, segment: 7
# .\data\genre_dataset\blues\blues.00072.wav, segment: 8
# .\data\genre_dataset\blues\blues.00072.wav, segment: 9
# .\data\genre_dataset\blues\blues.00072.wav, segment: 10
# .\data\genre_dataset\blues\blues.00073.wav, segment: 1
# .\data\genre_dataset\blues\blues.00073.wav, segment: 2
# .\data\genre_dataset\blues\blues.00073.wav, segment: 3
# .\data\genre_dataset\blues\blues.00073.wav, segment: 4
# .\data\genre_dataset\blues\blues.00073.wav, segment: 5
# .\data\genre_dataset\blues\blues.00073.wav, segment: 6
# .\data\genre_dataset\blues\blues.00073.wav, segment: 7
# .\data\genre_dataset\blues\blues.00073.wav, segment: 8
# .\data\genre_dataset\blues\blues.00073.wav, segment: 9
# .\data\genre_dataset\blues\blues.00073.wav, segment: 10
# .\data\genre_dataset\blues\blues.00074.wav, segment: 1
# .\data\genre_dataset\blues\blues.00074.wav, segment: 2
# .\data\genre_dataset\blues\blues.00074.wav, segment: 3
# .\data\genre_dataset\blues\blues.00074.wav, segment: 4
# .\data\genre_dataset\blues\blues.00074.wav, segment: 5
# .\data\genre_dataset\blues\blues.00074.wav, segment: 6
# .\data\genre_dataset\blues\blues.00074.wav, segment: 7
# .\data\genre_dataset\blues\blues.00074.wav, segment: 8
# .\data\genre_dataset\blues\blues.00074.wav, segment: 9
# .\data\genre_dataset\blues\blues.00074.wav, segment: 10
# .\data\genre_dataset\blues\blues.00075.wav, segment: 1
# .\data\genre_dataset\blues\blues.00075.wav, segment: 2
# .\data\genre_dataset\blues\blues.00075.wav, segment: 3
# .\data\genre_dataset\blues\blues.00075.wav, segment: 4
# .\data\genre_dataset\blues\blues.00075.wav, segment: 5
# .\data\genre_dataset\blues\blues.00075.wav, segment: 6
# .\data\genre_dataset\blues\blues.00075.wav, segment: 7
# .\data\genre_dataset\blues\blues.00075.wav, segment: 8
# .\data\genre_dataset\blues\blues.00075.wav, segment: 9
# .\data\genre_dataset\blues\blues.00075.wav, segment: 10
# .\data\genre_dataset\blues\blues.00076.wav, segment: 1
# .\data\genre_dataset\blues\blues.00076.wav, segment: 2
# .\data\genre_dataset\blues\blues.00076.wav, segment: 3
# .\data\genre_dataset\blues\blues.00076.wav, segment: 4
# .\data\genre_dataset\blues\blues.00076.wav, segment: 5
# .\data\genre_dataset\blues\blues.00076.wav, segment: 6
# .\data\genre_dataset\blues\blues.00076.wav, segment: 7
# .\data\genre_dataset\blues\blues.00076.wav, segment: 8
# .\data\genre_dataset\blues\blues.00076.wav, segment: 9
# .\data\genre_dataset\blues\blues.00076.wav, segment: 10
# .\data\genre_dataset\blues\blues.00077.wav, segment: 1
# .\data\genre_dataset\blues\blues.00077.wav, segment: 2
# .\data\genre_dataset\blues\blues.00077.wav, segment: 3
# .\data\genre_dataset\blues\blues.00077.wav, segment: 4
# .\data\genre_dataset\blues\blues.00077.wav, segment: 5
# .\data\genre_dataset\blues\blues.00077.wav, segment: 6
# .\data\genre_dataset\blues\blues.00077.wav, segment: 7
# .\data\genre_dataset\blues\blues.00077.wav, segment: 8
# .\data\genre_dataset\blues\blues.00077.wav, segment: 9
# .\data\genre_dataset\blues\blues.00077.wav, segment: 10
# .\data\genre_dataset\blues\blues.00078.wav, segment: 1
# .\data\genre_dataset\blues\blues.00078.wav, segment: 2
# .\data\genre_dataset\blues\blues.00078.wav, segment: 3
# .\data\genre_dataset\blues\blues.00078.wav, segment: 4
# .\data\genre_dataset\blues\blues.00078.wav, segment: 5
# .\data\genre_dataset\blues\blues.00078.wav, segment: 6
# .\data\genre_dataset\blues\blues.00078.wav, segment: 7
# .\data\genre_dataset\blues\blues.00078.wav, segment: 8
# .\data\genre_dataset\blues\blues.00078.wav, segment: 9
# .\data\genre_dataset\blues\blues.00078.wav, segment: 10
# .\data\genre_dataset\blues\blues.00079.wav, segment: 1
# .\data\genre_dataset\blues\blues.00079.wav, segment: 2
# .\data\genre_dataset\blues\blues.00079.wav, segment: 3
# .\data\genre_dataset\blues\blues.00079.wav, segment: 4
# .\data\genre_dataset\blues\blues.00079.wav, segment: 5
# .\data\genre_dataset\blues\blues.00079.wav, segment: 6
# .\data\genre_dataset\blues\blues.00079.wav, segment: 7
# .\data\genre_dataset\blues\blues.00079.wav, segment: 8
# .\data\genre_dataset\blues\blues.00079.wav, segment: 9
# .\data\genre_dataset\blues\blues.00079.wav, segment: 10
# .\data\genre_dataset\blues\blues.00080.wav, segment: 1
# .\data\genre_dataset\blues\blues.00080.wav, segment: 2
# .\data\genre_dataset\blues\blues.00080.wav, segment: 3
# .\data\genre_dataset\blues\blues.00080.wav, segment: 4
# .\data\genre_dataset\blues\blues.00080.wav, segment: 5
# .\data\genre_dataset\blues\blues.00080.wav, segment: 6
# .\data\genre_dataset\blues\blues.00080.wav, segment: 7
# .\data\genre_dataset\blues\blues.00080.wav, segment: 8
# .\data\genre_dataset\blues\blues.00080.wav, segment: 9
# .\data\genre_dataset\blues\blues.00080.wav, segment: 10
# .\data\genre_dataset\blues\blues.00081.wav, segment: 1
# .\data\genre_dataset\blues\blues.00081.wav, segment: 2
# .\data\genre_dataset\blues\blues.00081.wav, segment: 3
# .\data\genre_dataset\blues\blues.00081.wav, segment: 4
# .\data\genre_dataset\blues\blues.00081.wav, segment: 5
# .\data\genre_dataset\blues\blues.00081.wav, segment: 6
# .\data\genre_dataset\blues\blues.00081.wav, segment: 7
# .\data\genre_dataset\blues\blues.00081.wav, segment: 8
# .\data\genre_dataset\blues\blues.00081.wav, segment: 9
# .\data\genre_dataset\blues\blues.00081.wav, segment: 10
# .\data\genre_dataset\blues\blues.00082.wav, segment: 1
# .\data\genre_dataset\blues\blues.00082.wav, segment: 2
# .\data\genre_dataset\blues\blues.00082.wav, segment: 3
# .\data\genre_dataset\blues\blues.00082.wav, segment: 4
# .\data\genre_dataset\blues\blues.00082.wav, segment: 5
# .\data\genre_dataset\blues\blues.00082.wav, segment: 6
# .\data\genre_dataset\blues\blues.00082.wav, segment: 7
# .\data\genre_dataset\blues\blues.00082.wav, segment: 8
# .\data\genre_dataset\blues\blues.00082.wav, segment: 9
# .\data\genre_dataset\blues\blues.00082.wav, segment: 10
# .\data\genre_dataset\blues\blues.00083.wav, segment: 1
# .\data\genre_dataset\blues\blues.00083.wav, segment: 2
# .\data\genre_dataset\blues\blues.00083.wav, segment: 3
# .\data\genre_dataset\blues\blues.00083.wav, segment: 4
# .\data\genre_dataset\blues\blues.00083.wav, segment: 5
# .\data\genre_dataset\blues\blues.00083.wav, segment: 6
# .\data\genre_dataset\blues\blues.00083.wav, segment: 7
# .\data\genre_dataset\blues\blues.00083.wav, segment: 8
# .\data\genre_dataset\blues\blues.00083.wav, segment: 9
# .\data\genre_dataset\blues\blues.00083.wav, segment: 10
# .\data\genre_dataset\blues\blues.00084.wav, segment: 1
# .\data\genre_dataset\blues\blues.00084.wav, segment: 2
# .\data\genre_dataset\blues\blues.00084.wav, segment: 3
# .\data\genre_dataset\blues\blues.00084.wav, segment: 4
# .\data\genre_dataset\blues\blues.00084.wav, segment: 5
# .\data\genre_dataset\blues\blues.00084.wav, segment: 6
# .\data\genre_dataset\blues\blues.00084.wav, segment: 7
# .\data\genre_dataset\blues\blues.00084.wav, segment: 8
# .\data\genre_dataset\blues\blues.00084.wav, segment: 9
# .\data\genre_dataset\blues\blues.00084.wav, segment: 10
# .\data\genre_dataset\blues\blues.00085.wav, segment: 1
# .\data\genre_dataset\blues\blues.00085.wav, segment: 2
# .\data\genre_dataset\blues\blues.00085.wav, segment: 3
# .\data\genre_dataset\blues\blues.00085.wav, segment: 4
# .\data\genre_dataset\blues\blues.00085.wav, segment: 5
# .\data\genre_dataset\blues\blues.00085.wav, segment: 6
# .\data\genre_dataset\blues\blues.00085.wav, segment: 7
# .\data\genre_dataset\blues\blues.00085.wav, segment: 8
# .\data\genre_dataset\blues\blues.00085.wav, segment: 9
# .\data\genre_dataset\blues\blues.00085.wav, segment: 10
# .\data\genre_dataset\blues\blues.00086.wav, segment: 1
# .\data\genre_dataset\blues\blues.00086.wav, segment: 2
# .\data\genre_dataset\blues\blues.00086.wav, segment: 3
# .\data\genre_dataset\blues\blues.00086.wav, segment: 4
# .\data\genre_dataset\blues\blues.00086.wav, segment: 5
# .\data\genre_dataset\blues\blues.00086.wav, segment: 6
# .\data\genre_dataset\blues\blues.00086.wav, segment: 7
# .\data\genre_dataset\blues\blues.00086.wav, segment: 8
# .\data\genre_dataset\blues\blues.00086.wav, segment: 9
# .\data\genre_dataset\blues\blues.00086.wav, segment: 10
# ...
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00030.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00031.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00032.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00033.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00034.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00035.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00036.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00037.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00038.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00039.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00040.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00041.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00042.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00043.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00044.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00045.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00046.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00047.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00048.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00049.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00050.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00051.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00052.wav, segment: 10
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 1
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 2
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 3
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 4
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 5
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 6
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 7
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 8
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 9
# .\data\genre_dataset\jazz\jazz.00053.wav, segment: 10
# C:\Users\pbeata\anaconda3\envs\py3-TF2.0\lib\site-packages\librosa\core\audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\py3-TF2.0\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# ~\anaconda3\envs\py3-TF2.0\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ~\anaconda3\envs\py3-TF2.0\lib\site-packages\soundfile.py in _open(self, file, mode_int, closefd)
#    1182             raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183         _error_check(_snd.sf_error(file_ptr),
#    1184                      "Error opening {0!r}: ".format(self.name))
#
# ~\anaconda3\envs\py3-TF2.0\lib\site-packages\soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening '.\\data\\genre_dataset\\jazz\\jazz.00054.wav': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# <ipython-input-23-dcefefd7b3fe> in <module>
#       1 # test with reduced dataset
# ----> 2 save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
#
# <ipython-input-22-e55fbef02945> in save_mfcc(dataset_path, json_path, n_mfcc, n_fft, hop_length, num_segments)
#      37                 # need file path to load the audio file
#      38                 file_path = os.path.join(dir_path, f)
# ---> 39                 signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
#      40
#      41                 # process segments extracting MFCC and storing data
#
# ~\anaconda3\envs\py3-TF2.0\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     164         if isinstance(path, (str, pathlib.PurePath)):
#     165             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 166             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     167         else:
#     168             raise (exc)
#
# ~\anaconda3\envs\py3-TF2.0\lib\site-packages\librosa\core\audio.py in __audioread_load(path, offset, duration, dtype)
#     188
#     189     y = []
# --> 190     with audioread.audio_open(path) as input_file:
#     191         sr_native = input_file.samplerate
#     192         n_channels = input_file.channels
#
# ~\anaconda3\envs\py3-TF2.0\lib\site-packages\audioread\__init__.py in audio_open(path, backends)
#     114
#     115     # All backends failed!
# --> 116     raise NoBackendError()
#
# NoBackendError:
